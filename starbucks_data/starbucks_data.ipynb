# %%
import pandas as pd
df = pd.read_csv('starbucks.csv', header = None)
df
# Out:
#                              0                                             1   \
# 0             Beverage_category                                      Beverage
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4                        Coffee                                 Brewed Coffee
# ..                          ...                                           ...
# 238  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 242  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Calories'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df['Calories']
#
# ...

# %%
df.columns = headers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.columns = headers
#
# NameError: name 'headers' is not defined

# %%
df[:26362]
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df[26362:26363]
# Out:
#       ticker        commodity        date       open       high        low  \
# 26362   BZ=F  Brent Crude Oil  02-02-2021  56.290001  58.049999  56.220001
#
#            close  volume
# 26362  57.459999   34815

# %%
df.columns
# Out:
# Index(['ticker', 'commodity', 'date', 'open', 'high', 'low', 'close',
#        'volume'],
#       dtype='object')

# %%
df.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.row
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
df.date
# Out:
# 0        23-08-2000
# 1        24-08-2000
# 2        25-08-2000
# 3        28-08-2000
# 4        29-08-2000
#             ...
# 26995    10-08-2023
# 26996    11-08-2023
# 26997    14-08-2023
# 26998    15-08-2023
# 26999    16-08-2023
# Name: date, Length: 27000, dtype: object

# %%
type(['date'])
# Out:
# list

# %%
df[['date','high','low']]
# Out:
#              date       high        low
# 0      23-08-2000  32.799999  31.950001
# 1      24-08-2000  32.240002  31.400000
# 2      25-08-2000  32.099998  31.320000
# 3      28-08-2000  32.919998  31.860001
# 4      29-08-2000  33.029999  32.560001
# ...           ...        ...        ...
# 26995  10-08-2023  88.099998  86.150002
# 26996  11-08-2023  87.349998  85.849998
# 26997  14-08-2023  86.699997  85.500000
# 26998  15-08-2023  86.669998  84.290001
# 26999  16-08-2023  85.360001  83.120003
#
# [27000 rows x 3 columns]

# %%
df.describe()
# Out:
#                open          high           low         close        volume
# count  27000.000000  27000.000000  27000.000000  27000.000000  2.700000e+04
# mean      27.008849     27.397822     26.594791     27.007317  1.055767e+05
# std       35.933468     36.386133     35.447228     35.937274  1.495351e+05
# min      -14.000000      0.507000    -40.320000    -37.630001  0.000000e+00
# 25%        2.002050      2.034975      1.971150      2.001000  2.609175e+04
# 50%        3.437000      3.518550      3.354350      3.436400  4.859250e+04
# 75%       53.422499     54.212500     52.565001     53.462500  1.126950e+05
# max      146.080002    147.429993    144.270004    146.080002  2.288230e+06

# %%
df[df['open']==df['open'].max()]
# Out:
#       ticker        commodity        date        open        high         low  \
# 23254   BZ=F  Brent Crude Oil  03-07-2008  146.080002  146.270004  144.270004
#
#             close  volume
# 23254  146.080002    1064

# %%
df.loc[3]
# Out:
# ticker             CL=F
# commodity     Crude Oil
# date         28-08-2000
# open          32.040001
# high          32.919998
# low           31.860001
# close         32.869999
# volume            46770
# Name: 3, dtype: object

# %%
 df.set_index('date', inplace=True)

# %%
df
# Out:
#            ticker        commodity       open       high        low  \
# date
# 23-08-2000   CL=F        Crude Oil  31.950001  32.799999  31.950001
