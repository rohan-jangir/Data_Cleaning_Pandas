# %% [markdown]
# # import liabraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rohan\\OneDrive\\Desktop\\data analyst\\Projects\\fuels project'

# %% [markdown]
# # Starting 10 Rows

# %%
df = pd.read_csv('fuels.csv')
df
# Out:
#       ticker        commodity        date       open       high        low  \
# 0       CL=F        Crude Oil  23-08-2000  31.950001  32.799999  31.950001
# 1       CL=F        Crude Oil  24-08-2000  31.900000  32.240002  31.400000
# 2       CL=F        Crude Oil  25-08-2000  31.700001  32.099998  31.320000
# 3       CL=F        Crude Oil  28-08-2000  32.040001  32.919998  31.860001
# 4       CL=F        Crude Oil  29-08-2000  32.820000  33.029999  32.560001
# ...      ...              ...         ...        ...        ...        ...
# 26995   BZ=F  Brent Crude Oil  10-08-2023  87.370003  88.099998  86.150002
# 26996   BZ=F  Brent Crude Oil  11-08-2023  86.389999  87.349998  85.849998
# 26997   BZ=F  Brent Crude Oil  14-08-2023  86.639999  86.699997  85.500000
# 26998   BZ=F  Brent Crude Oil  15-08-2023  86.300003  86.669998  84.290001
# 26999   BZ=F  Brent Crude Oil  16-08-2023  85.120003  85.360001  83.120003
#
#            close  volume
# 0      32.049999   79385
# ...

# %% [markdown]
# # Get information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27000 entries, 0 to 26999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ticker     27000 non-null  object
#  1   commodity  27000 non-null  object
#  2   date       27000 non-null  object
#  3   open       27000 non-null  float64
#  4   high       27000 non-null  float64
#  5   low        27000 non-null  float64
#  6   close      27000 non-null  float64
#  7   volume     27000 non-null  int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# # Find Column Names

# %%
df.columns
# Out:
# Index(['ticker', 'commodity', 'date', 'open', 'high', 'low', 'close',
#        'volume'],
#       dtype='object')

# %% [markdown]
# # Describe About all Values

# %%
df.describe()
# Out:
#                open          high           low         close        volume
# count  27000.000000  27000.000000  27000.000000  27000.000000  2.700000e+04
# mean      27.008849     27.397822     26.594791     27.007317  1.055767e+05
# std       35.933468     36.386133     35.447228     35.937274  1.495351e+05
# min      -14.000000      0.507000    -40.320000    -37.630001  0.000000e+00
# 25%        2.002050      2.034975      1.971150      2.001000  2.609175e+04
# 50%        3.437000      3.518550      3.354350      3.436400  4.859250e+04
# 75%       53.422499     54.212500     52.565001     53.462500  1.126950e+05
# max      146.080002    147.429993    144.270004    146.080002  2.288230e+06

# %%
df.isnull().sum()
# Out:
# ticker       0
# commodity    0
# date         0
# open         0
# high         0
# low          0
# close        0
# volume       0
# dtype: int64

# %%
pd.get_dummies(df['commodity'])
# Out:
#        Brent Crude Oil  Crude Oil  Heating Oil  Natural Gas  RBOB Gasoline
# 0                False       True        False        False          False
# 1                False       True        False        False          False
# 2                False       True        False        False          False
# 3                False       True        False        False          False
# 4                False       True        False        False          False
# ...                ...        ...          ...          ...            ...
# 26995             True      False        False        False          False
# 26996             True      False        False        False          False
# 26997             True      False        False        False          False
# 26998             True      False        False        False          False
# 26999             True      False        False        False          False
#
# [27000 rows x 5 columns]

# %% [markdown]
# # Pie Chart

# %%
commodity_open = df.groupby('commodity')['open'].sum()
# plt.figure(figsize=(10,8))
plt.pie(commodity_data,labels=commodity_open.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.legend(loc='lower right',shadow=True,fontsize='6')
plt.title('Open sales for diffrent oils')
plt.show()

# %%
commodity_high = df.groupby('commodity')['high'].sum()
plt.pie(commodity_high,labels=commodity_high.index,autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('high sale for diffrent commodity')
plt.legend(loc='lower right',shadow=True,fontsize='6')
plt.show()

# %%
commodity_low = df.groupby('commodity')['low'].sum()
plt.pie(commodity_low,labels=commodity_low.index,autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('low sale for diffrent commodity')
plt.legend(loc='lower right',shadow=True,fontsize='6')
plt.show()

# %%
commodity_close = df.groupby('commodity')['close'].sum()
plt.pie(commodity_close,labels=commodity_close.index,autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('close sale for diffrent commodity')
plt.legend(loc='lower right',shadow=True,fontsize='6')
plt.show()

# %%
commodity_volume = df.groupby('commodity')['volume'].sum()
plt.pie(commodity_volume,labels=commodity_volume.index,autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('close sale for diffrent commodity')
plt.legend(loc='lower right',shadow=True,fontsize='6')
plt.show()

# %% [markdown]
# # Bar Chart

# %%
c = df['commodity']
d = df['open']
plt.bar(c,d)
plt.legend(loc='best',shadow=True)
plt.xticks(rotation=10)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
a = df['commodity']
b = df['high']
plt.bar(a,b)
plt.xticks(rotation=10)
plt.show()

# %%
e = df['commodity']
f = df['low']
plt.bar(e,f)
plt.xticks(rotation=10)
plt.show()

# %%
g = df['commodity']
h = df['close']
plt.bar(g,h)
plt.xticks(rotation=10)
plt.show()

# %%
i = df['commodity']
j = df['volume']
plt.bar(i,j)
plt.xticks(rotation=10)
plt.show()

# %%
gg = df.groupby('commodity')['high','open','low','close','volume'].sum()
gg
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_4892\1090755078.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   gg = df.groupby('commodity')['high','open','low','close','volume'].sum()
#                           high           open            low          close  \
# commodity
# Brent Crude Oil  316018.409795  312197.460103  308145.170226  312209.239921
# Crude Oil        374435.269956  368710.499925  362560.140031  368686.029987
# Heating Oil       11454.243997   11286.534501   11114.946999   11283.846096
# Natural Gas       26838.743985   26218.349987   25588.754004   26187.413997
# RBOB Gasoline     10994.519202   10826.079502   10650.355600   10831.031301
#
#                      volume
# commodity
# Brent Crude Oil    67271460
# Crude Oil        1751174934
# Heating Oil       220165203
# Natural Gas       582531795
# RBOB Gasoline     229427722

# %%
print(gg.index)
# Out:
# Index(['Brent Crude Oil', 'Crude Oil', 'Heating Oil', 'Natural Gas',
#        'RBOB Gasoline'],
#       dtype='object', name='commodity')

# %%
jj = gg.sum()
jj
# Out:
# high      7.397412e+05
# open      7.292389e+05
# low       7.180594e+05
# close     7.291976e+05
# volume    2.850571e+09
# dtype: float64

# %%
data1 = df.sort_values(by='high', ascending=False)
data1.head(10)
p = df['high']
c = data1.index
# Out:
#       ticker        commodity        date        open        high         low  \
# 23254   BZ=F  Brent Crude Oil  03-07-2008  146.080002  146.270004  144.270004
# 1965    CL=F        Crude Oil  03-07-2008  144.190002  145.850006  143.220001
# 1971    CL=F        Crude Oil  14-07-2008  144.690002  146.369995  142.490005
# 23260   BZ=F  Brent Crude Oil  14-07-2008  143.759995  145.240005  142.309998
# 23259   BZ=F  Brent Crude Oil  11-07-2008  144.759995  147.429993  141.649994
# 1970    CL=F        Crude Oil  11-07-2008  141.800003  147.270004  141.440002
# 23253   BZ=F  Brent Crude Oil  02-07-2008  141.639999  144.899994  140.490005
# 23255   BZ=F  Brent Crude Oil  07-07-2008  143.270004  143.949997  140.369995
# 23252   BZ=F  Brent Crude Oil  01-07-2008  141.600006  143.360001  140.320007
# 1964    CL=F        Crude Oil  02-07-2008  141.440002  144.320007  140.009995
#
#             close  volume
# 23254  146.080002    1064
# 1965   145.289993  193841
# 1971   145.179993  252605
# ...

# %%
data1.index
# Out:
# Int64Index([23254,  1965,  1971, 23260, 23259,  1970, 23253, 23255, 23252,
#              1964,
#             ...
#             22167, 17556, 17555, 17557, 22183, 22164, 22163, 22162,  4932,
#              4931],
#            dtype='int64', length=27000)

# %%
a = df.groupby('commodity')
for b,c in a:
    print(b)
    print(commo)
# Out:
# Brent Crude Oil
#       ticker      commodity        date    open    high     low   close  \
# 17296   RB=F  RBOB Gasoline  01-11-2000  0.8890  0.8970  0.8820  0.8840
# 17297   RB=F  RBOB Gasoline  02-11-2000  0.8750  0.8876  0.8630  0.8688
# 17298   RB=F  RBOB Gasoline  03-11-2000  0.8675  0.8750  0.8600  0.8695
# 17299   RB=F  RBOB Gasoline  06-11-2000  0.8600  0.8850  0.8560  0.8825
# 17300   RB=F  RBOB Gasoline  07-11-2000  0.8930  0.9000  0.8860  0.8910
# ...      ...            ...         ...     ...     ...     ...     ...
# 23014   RB=F  RBOB Gasoline  10-08-2023  2.9316  2.9443  2.8670  2.9047
# 23015   RB=F  RBOB Gasoline  11-08-2023  2.9037  2.9859  2.8993  2.9649
# 23016   RB=F  RBOB Gasoline  14-08-2023  2.9490  2.9490  2.8848  2.9062
# 23017   RB=F  RBOB Gasoline  15-08-2023  2.9054  2.9318  2.8388  2.8476
# 23018   RB=F  RBOB Gasoline  16-08-2023  2.8461  2.8835  2.8192  2.8671
#
#        volume
# 17296   16223
# 17297   17216
# 17298   10170
# 17299   16184
# ...

# %%
a = df[['commodity','open']]
b = a.groupby('commodity')
b.max()
# Out:
#                        open
# commodity
# Brent Crude Oil  146.080002
# Crude Oil        145.190002
# Heating Oil        4.928300
# Natural Gas       15.160000
# RBOB Gasoline      4.272500

# %%
x = df[['open','close']]
g = np.reshape(x,(-1,1))
sns.pairplot(df,hue=g)
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1246: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if hue in numeric_cols:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 x = df[['open','close']]
#       2 g = np.reshape(x,(-1,1))
# ----> 3 sns.pairplot(df,hue=g)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2114, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2112 # Set up the PairGrid
#    2113 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2114 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2115                 hue_order=hue_order, palette=palette, corner=corner,
# ...
