# %%
import pandas as pd
df = pd.read_csv("xx.csv")
df['Suppressed'] = df['Magnitude']
df['Suppressed'][10:11] = ''
df.to_csv('xx.csv')
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_6028\1590167907.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Suppressed'][10:11] = ''

# %%
df['Suppressed'] = ''
df.to_csv('xx.csv')
df.dropna(subset = ['Suppressed'], axis = 1, inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6028\4085449353.py in ?()
#       1 df['Suppressed'] = ''
#       2 df.to_csv('xx.csv')
# ----> 3 df.dropna(subset = ['Suppressed'], axis = 1, inplace = True)
#       4 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6403             ax = self._get_axis(agg_axis)
#    6404             indices = ax.get_indexer_for(subset)
#    6405             check = indices == -1
#    6406             if check.any():
# -> 6407                 raise KeyError(np.array(subset)[check].tolist())
#    6408             agg_obj = self.take(indices, axis=agg_axis)
#    6409
#    6410         if thresh is not no_default:
#
# KeyError: ['Suppressed']

# %%
import pandas as pd
import numpy as nx
df = pd.read_csv("xx.csv")
df
# Out:
#     Unnamed: 0 Series_reference   Period  Data_value  Suppressed STATUS  \
# 0            0    BDCQ.SF1AA2CA  2016.06    1116.386         1.0      F
# 1            1    BDCQ.SF1AA2CA  2016.09    1070.874         1.0      F
# 2            2    BDCQ.SF1AA2CA  2016.12    1054.408         1.0      F
# 3            3    BDCQ.SF1AA2CA  2017.03    1010.665         1.0      F
# 4            4    BDCQ.SF1AA2CA  2017.06    1233.700         1.0      F
# 5            5    BDCQ.SF1AA2CA  2017.09    1282.436         1.0      F
# 6            6    BDCQ.SF1AA2CA  2017.12    1290.820         1.0      F
# 7            7    BDCQ.SF1AA2CA  2018.03    1412.007         1.0      F
# 8            8    BDCQ.SF1AA2CA  2018.06    1488.055         NaN      F
# 9            9    BDCQ.SF1AA2CA  2018.09    1497.678         1.0      F
# 10          10    BDCQ.SF1AA2CA  2018.12    1570.507         1.0      F
# 11          11    BDCQ.SF1AA2CA  2019.03    1393.749         1.0      F
# ...

# %%
# df['Suppressed'].astype(int)
a = df['Magnitude'].mean()
df['Suppressed'].replace(np.nan,a, inplace = True)
# Out:
# 6.0

# %%
# df['Data_value'] = df['Data_value']/df['Suppressed']

a = int(235/19)
print(a)
# Out:
# 12

# %%
df['Suppressed'] = df['Suppressed'].astype('int')
df.dtypes
# Out:
# Unnamed: 0            int64
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed            int32
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# dtype: object

# %%
df['Suppressed'].replace(6,np.nan, inplace = True)
df
# Out:
#     Unnamed: 0 Series_reference   Period  Data_value  Suppressed STATUS  \
# 0            0    BDCQ.SF1AA2CA  2016.06   31.010722         NaN      F
# 1            1    BDCQ.SF1AA2CA  2016.09   29.746500         NaN      F
# 2            2    BDCQ.SF1AA2CA  2016.12   29.289111         NaN      F
# 3            3    BDCQ.SF1AA2CA  2017.03   28.074028         NaN      F
# 4            4    BDCQ.SF1AA2CA  2017.06   34.269444         NaN      F
# 5            5    BDCQ.SF1AA2CA  2017.09   35.623222         NaN      F
# 6            6    BDCQ.SF1AA2CA  2017.12   35.856111         NaN      F
# 7            7    BDCQ.SF1AA2CA  2018.03   39.222417         NaN      F
# 8            8    BDCQ.SF1AA2CA  2018.06   41.334861         NaN      F
# 9            9    BDCQ.SF1AA2CA  2018.09   41.602167         NaN      F
# 10          10    BDCQ.SF1AA2CA  2018.12   43.625194         NaN      F
# 11          11    BDCQ.SF1AA2CA  2019.03   38.715250         NaN      F
# ...

# %%
df['Magnitude'] = df['Magnitude']/df['Magnitude'].max()
df
# Out:
#     Unnamed: 0 Series_reference   Period  Data_value  Suppressed STATUS  \
# 0            0    BDCQ.SF1AA2CA  2016.06    0.611139         NaN      F
# 1            1    BDCQ.SF1AA2CA  2016.09    0.586225         NaN      F
# 2            2    BDCQ.SF1AA2CA  2016.12    0.577211         NaN      F
# 3            3    BDCQ.SF1AA2CA  2017.03    0.553265         NaN      F
# 4            4    BDCQ.SF1AA2CA  2017.06    0.675360         NaN      F
# 5            5    BDCQ.SF1AA2CA  2017.09    0.702039         NaN      F
# 6            6    BDCQ.SF1AA2CA  2017.12    0.706629         NaN      F
# 7            7    BDCQ.SF1AA2CA  2018.03    0.772970         NaN      F
# 8            8    BDCQ.SF1AA2CA  2018.06    0.814600         NaN      F
# 9            9    BDCQ.SF1AA2CA  2018.09    0.819868         NaN      F
# 10          10    BDCQ.SF1AA2CA  2018.12    0.859737         NaN      F
# 11          11    BDCQ.SF1AA2CA  2019.03    0.762975         NaN      F
# ...

# %%
df = pd.read_csv('xx.csv', header = None, usecols = [1,2,3])
df.columns = ['a','b','c']
df
# Out:
#                    a        b           c
# 0   Series_reference   Period  Data_value
# 1      BDCQ.SF1AA2CA  2016.06    1116.386
# 2      BDCQ.SF1AA2CA  2016.09    1070.874
# 3      BDCQ.SF1AA2CA  2016.12    1054.408
# 4      BDCQ.SF1AA2CA  2017.03    1010.665
# 5      BDCQ.SF1AA2CA  2017.06      1233.7
# 6      BDCQ.SF1AA2CA  2017.09    1282.436
# 7      BDCQ.SF1AA2CA  2017.12     1290.82
# 8      BDCQ.SF1AA2CA  2018.03    1412.007
# 9      BDCQ.SF1AA2CA  2018.06    1488.055
# 10     BDCQ.SF1AA2CA  2018.09    1497.678
# 11     BDCQ.SF1AA2CA  2018.12    1570.507
# 12     BDCQ.SF1AA2CA  2019.03    1393.749
# 13     BDCQ.SF1AA2CA  2019.06    1517.143
# 14     BDCQ.SF1AA2CA  2019.09    1381.514
# 15     BDCQ.SF1AA2CA  2019.12    1370.985
# 16     BDCQ.SF1AA2CA  2020.03    1073.017
# 17     BDCQ.SF1AA2CA  2020.06    1131.445
# 18     BDCQ.SF1AA2CA  2020.09    1440.101
# 19     BDCQ.SF1AA2CA  2020.12    1489.979
# 20     BDCQ.SF1AA2CA  2021.03    1390.782
# ...
